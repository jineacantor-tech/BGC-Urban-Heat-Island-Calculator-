# %% [markdown]
# <a href="https://colab.research.google.com/github/jineacantor-tech/BGC-Urban-Heat-Island-Calculator-/blob/main/UHIC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ====================================================================
# SCRIPT 3: BGC URBAN HEAT ISLAND CALCULATOR
# ====================================================================

# Surface temperatures recorded in Celsius (°C) across Taguig City
taguig_surface_temps = [32.4, 35.8, 31.2, 38.6, 33.1, 34.5]

# Automatically identifying the absolute maximum extreme temperature
peak_urban_heat = max(taguig_surface_temps)

# Printing a stylized report ready for a research portfolio
print("--- TAGUIG CLIMATE DATA LOG ---")
print(f"The highest microclimate temperature recorded is: {peak_urban_heat}°C")
print("Data source: Simulated Thermal Satellite Pixel Analysis")
print("--------------------------------")
# Out:
# --- TAGUIG CLIMATE DATA LOG ---
# The highest microclimate temperature recorded is: 38.6°C
# Data source: Simulated Thermal Satellite Pixel Analysis
# --------------------------------
